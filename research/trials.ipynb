# %%
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone as PineconeStore
from langchain.document_loaders import PyPDFLoader,DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import ctransformers
from langchain.llms import CTransformers
import pinecone

# %%
PINECONE_API_KEY = "3b6967cd-0235-4073-9d75-31e3ff580e38"

# %%
#extracting daata from the pdf
def load_pdf(data):
    loader = DirectoryLoader(data,glob="*.pdf",loader_cls=PyPDFLoader)

    documents = loader.load()

    return documents

# %%
extracted_data = load_pdf("data/")

# %%
# creating data Chunks

def text_split(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size = 40,chunk_overlap = 15)
    text_chunks = text_splitter.split_documents(extracted_data)

    return text_chunks

# %%
text_chunks = text_split(extracted_data)
print("length of my chunk:", len(text_chunks))
# Out:
# length of my chunk: 3125

# %%
#downloading embedding model 
def download_hugging_face_embedings():
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    return embeddings

# %%
embedding = download_hugging_face_embedings()
# Out:
# c:\Hardik\Ai_tools\Chatbot_using_LLama2\Bot\lib\site-packages\huggingface_hub\file_download.py:148: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\bhaga\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
embedding
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %%
query_result = embedding.embed_query("Hello World")
print("Length", len(query_result))
# Out:
# Length 384

# %%
query_result
# Out:
# [-0.034477222710847855,
#  0.031023189425468445,
#  0.00673493230715394,
#  0.02610897831618786,
#  -0.03936203941702843,
#  -0.16030248999595642,
#  0.06692398339509964,
#  -0.006441492587327957,
#  -0.04745054617524147,
#  0.01475894171744585,
#  0.07087540626525879,
#  0.05552757903933525,
#  0.019193286076188087,
#  -0.026251375675201416,
#  -0.010109512135386467,
#  -0.026940539479255676,
#  0.022307513281702995,
#  -0.022226620465517044,
#  -0.14969266951084137,
#  -0.017493048682808876,
#  0.00767626753076911,
#  0.0543522946536541,
#  0.003254437353461981,
#  0.03172598034143448,
#  -0.0846213847398758,
#  -0.029406018555164337,
#  0.05159567669034004,
#  0.048124030232429504,
#  -0.0033148014917969704,
#  -0.05827920511364937,
#  0.04196932911872864,
#  0.022210698574781418,
#  0.12818889319896698,
#  -0.022338908165693283,
#  -0.011656295508146286,
#  0.06292832642793655,
#  -0.03287626430392265,
#  -0.09122607111930847,
#  -0.03117542713880539,
#  0.052699606865644455,
#  0.0470348484814167,
#  -0.08420299738645554,
#  -0.030056146904826164,
#  -0.020744740962982178,
#  0.009517806582152843,
#  -0.003721754066646099,
#  0.007343400735408068,
#  0.0393243245780468,
#  0.09327412396669388,
#  -0.003788660280406475,
#  -0.05274209380149841,
#  -0.058058179914951324,
#  -0.006864393129944801,
#  0.005283208563923836,
#  0.08289302885532379,
#  0.019362719729542732,
#  0.006284467875957489,
#  -0.010330799035727978,
#  0.009032361209392548,
#  -0.03768374025821686,
#  -0.04520608112215996,
#  0.024016406387090683,
#  -0.006944221444427967,
#  0.013491588644683361,
#  0.1000550389289856,
#  -0.07168388366699219,
#  -0.021695110946893692,
#  0.031618498265743256,
#  -0.05163465067744255,
#  -0.08224771171808243,
#  -0.06569333374500275,
#  -0.009895400144159794,
#  0.005816393531858921,
#  0.07355456799268723,
#  -0.034050289541482925,
#  0.02488614059984684,
#  0.014488041400909424,
#  0.02645743079483509,
#  0.009656773880124092,
#  0.030217353254556656,
#  0.05280391499400139,
#  -0.07535991817712784,
#  0.009897246025502682,
#  -0.024797873571515083,
#  0.014516300521790981,
#  -0.03706924617290497,
#  0.02001567929983139,
#  -4.859203181695193e-05,
#  0.009866567328572273,
#  0.024838829413056374,
#  -0.05245809257030487,
#  0.02931414544582367,
#  -0.08719193935394287,
#  -0.014499787241220474,
#  0.026019079610705376,
#  -0.01874641887843609,
#  -0.07620512694120407,
#  0.03504328802227974,
#  0.10363954305648804,
#  -0.028050515800714493,
#  0.01271822303533554,
#  -0.07632546871900558,
#  -0.018652385100722313,
#  0.024976631626486778,
#  0.08144541829824448,
#  0.06875895708799362,
#  -0.06405667960643768,
#  -0.08389390259981155,
#  0.061362382024526596,
#  -0.033545609563589096,
#  -0.10615337640047073,
#  -0.04008055850863457,
#  0.03253021836280823,
#  0.0766248106956482,
#  -0.07301609963178635,
#  0.0003375708474777639,
#  -0.04087156429886818,
#  -0.07578849047422409,
#  0.027527712285518646,
#  0.07462546229362488,
#  0.01771734096109867,
#  0.09121840447187424,
#  0.11022021621465683,
#  0.0005698088789358735,
#  0.05146335810422897,
#  -0.01455130334943533,
#  0.033232010900974274,
#  0.02379230223596096,
#  -0.022889776155352592,
#  0.03893757238984108,
#  0.030206819996237755]

# %%
text_chunks
# Out:
# [Document(page_content='About TSEC', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Thadomal Shahani  Engineering College -', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='College - MUMBAI > Governing Council &', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Council & Trust', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='The Hyderabad (Sind) National', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='National Collegiate Board well  known', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='well  known as HSNC board is a', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='board is a charitable trust', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='established by Sindhi Community in', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Community in 1949. The HSNC Board has', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='HSNC Board has roots going back over 60', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='back over 60 years. The', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='board was managing the National College', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='College in Hyderabad (Sind) long before', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='long before partition of India, In true', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='India, In true', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='spirit of their t imes the members of', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='the members of the Board worked to', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='worked to ensure the nations integrity', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='integrity and honour during', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='the National Movement of Indian', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='of Indian Independence. After the', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='After the Partition of the country in', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='the country in 1947, the', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='members of Sindhi Hindu Community', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Community migrated to India. Principal', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Principal K.M. Kundnan i, with the', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='i, with the vision and', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='mission to promote participation in', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='in education and initiated the efforts', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='the efforts for starting a college in', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='a college in Mumbai.', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='With active support and encouragement', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='encouragement from Late Barrister', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Late Barrister Hotchand G. Advani the', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='G. Advani the Hyderabad (Sind)', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='National Collegiate Board cam e into', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='cam e into existence in 1949 at Mumbai.', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='at Mumbai. Late Barrister H.G. Advani', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='H.G. Advani was the', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Founder President and Late Principal', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Late Principal K.M. Kundnani was the', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='was the Founder Secretary and Founder', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='and Founder Principal of', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='the first college started by the board', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='by the board and known as the Rishi', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='as the Rishi Dayaram National Coll ege,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Coll ege, Bandra, Mumbai', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='– 400 050.', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Since then the Board has been offering', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='been offering unique pre -degree study,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='-degree study, undergraduate and post', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='and post graduate', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='degrees in a wide range of programmes.', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='of programmes. It has produced', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='has produced professionals’ par', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='par excellence in the fields of', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Arts, Science, Commerce, M anagement,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='M anagement, Education, Law,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Law, Engineering, Technology and Para', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='and Para -Medical. The', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Institutions managed by the Board and', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='the Board and affiliated to the', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='to the University of Mumbai are as', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Mumbai are as follows:', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Rishi Dayaram National College of Arts', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='of Arts and Science, Bandra (W), Mumbai', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='(W), Mumbai – 400 050.', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Kishinc hand Chellaram College of Arts', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='of Arts and Science, Churchgate, Mumbai', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Mumbai – 400 020', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Kishinchand Chellaram Law College,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Law College, Churchgate, Mumbai -400020', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Mumbai -400020', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Hassaram Rijhumal College of Commerce', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='of Commerce and Economics, Churchgate,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Churchgate, Mumbai -400020', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Smt. Mithibai Motiram Kundnani College', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='College of C ommerce & Economics,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='& Economics, Bandra (W), Mumbai -400050', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Mumbai -400050', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Smt. Chandibai Himathmal Mansukhani', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Mansukhani College of Arts, Science and', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Science and Commerce, Ulhasnagar', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Ulhasnagar -421003', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Bombay Teachers’ Training College,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='College, Colaba, Mumbai -400005', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Prin. K.M. Kundnani College of', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='College of Pharmacy, Cuffe Parade, Mumb', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Parade, Mumb ai-400005.', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Gopaldas Jhamatmal Advani Law College,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Law College, Bandra (W), Mumbai -400050', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Mumbai -400050', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Watumull Institute of Electronics', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='of Electronics Engineering and Computer', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='and Computer Technology, Worli, Mumbai', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Worli, Mumbai -400018', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Thadomal Shahani Engineering College,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='College, Bandra (W), Mumbai -400050', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='HSNCB’s Dr. L.H. Hiranan dani Pharmacy', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='dani Pharmacy College, Ulhasnagar', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Ulhasnagar -421003', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='HSNCB’s H. & G. Himatmal Mansukhani', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Mansukhani Institute of Management,', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='of Management, Ulhasnagar -421003', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Nari Gursahani Law College, Ulhasnagar', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Ulhasnagar -421003', metadata={'source': 'data\\About TSEC.pdf', 'page': 0}),
#  Document(page_content='Prin. K.M. Kundnani Pharmacy', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Pharmacy Polytechnic, Ulhasnagar', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Ulhasnagar -421003', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Institute of Technology, Ulhasnagar', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Ulhasnagar -421003', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='K.C. College of Ma nagement Studies,', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Studies, Churchgate, Mumbai -400020', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='*In addition, there are several Higher', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='several Higher Secondary and Secondary', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='and Secondary Schools.', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='College Profile - Established in 1983,', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='in 1983, Thadomal Shahani Engineering', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Engineering College (TSEC), founded by', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Hyderabad (Sind) National Collegiate', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Collegiate Board, is recognized by', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='recognized by Government of', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Government of Maharashtra, approved by', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='All India Council for Technical', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='for Technical Education (AICTE) and', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='(AICTE) and Affiliated to University of', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='University of Mumbai. It offers a 4', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='It offers a 4 -year', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Bachelor of Engineering (B.E.) Degree', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='(B.E.) Degree program in Artificial', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='in Artificial Intelligence and data', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='and data Science, Information', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Technology, Computer Engineering,', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Engineering, Electronics & Teleco', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='& Teleco mmunication and Chemical', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='and Chemical Engineering. The', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='College offers Ph.D. program in the', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='program in the subject of Information', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='of Information Technology, Computer', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Computer Engineering, and', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Electronics & Telecommunication. At', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='At present we are enrolled with 40', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='with 40 research Scholars.', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='TSEC is hugely successful in creating', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='in creating an academic ambience where', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='ambience where learners increasingly', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='increasingly succeed in', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='unleashing their potential. The college', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='The college hugely succeeds in placing', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='in placing graduating students in', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='students in leading', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='enterprises (more than 90 enterprises', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='90 enterprises offer campus placement', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='placement  to our graduates) and', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='graduates) and facilitating them', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='for higher studies in the Post Graduate', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Post Graduate program of choice, in', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='of choice, in India and abroad. The', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='abroad. The college historically', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='performed to its fullest potential with', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='potential with best of class practises', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='practises and emerged as the most', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='as the most sought -after', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='engineeri ng college in the city of', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='in the city of Mumbai. It has emerged', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='It has emerged as a single point', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='a single point solution for the', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='for the students and', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='parents who are seeking professional', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='professional education in the realm of', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='the realm of engineering and our', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='and our professionalism', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='gets accentuated by enterprises in', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='enterprises in queue to roll out “offer', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='out “offer appointments” to our', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='to our graduating students.', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='We were keen on establishing quality', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='quality systems and procedures in', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='procedures in academic setting and', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='setting and eventually that', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='led to accreditation of our programs by', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='programs by National Board of', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Board of Accreditation in multiple', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='in multiple cycles. We are having', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='a syste m in place (Training and', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='(Training and Placement Cell) to', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Cell) to identify emerging / thrust', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='/ thrust areas in engineering and', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='integrate in the course curriculum. We', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='curriculum. We introduced courses like', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='courses like Artificial Intelligence,', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Intelligence, Machine Learning,', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Deep Learning and Blockchain Technology', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Technology in tandem with  the', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='with  the University to be abreast with', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='abreast with nascent', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='technologies. TSEC follows a gender', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='a gender agnostic and all -inclusive', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='all -inclusive academic ambience and', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='ambience and practises where', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='pupils thrive and emerge as productive', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='as productive entities over a period of', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='a period of four years of engagement.', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Principle - Dr. G.T. Thampi', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Position: Principal', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Academic Qualificati on:B.Sc. (Engg.)', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='(Engg.) Degree in Mechanical', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='in Mechanical Engineering, College of', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='College of Engineering,', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Trivandrum, University of Kerala (1984)', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='Kerala (1984) M.E. (Mechanical) with', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='with Machine Design subjects. V J T I,', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='V J T I, Mumbai', metadata={'source': 'data\\About TSEC.pdf', 'page': 1}),
#  Document(page_content='University (1997) Ph.D. (Technology),', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='(Technology), Mumbai University, (2004)', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='(2004)  Award Won : Received SHIKSHAK', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='SHIKSHAK RATAN', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='AWARD on 12TH October 2011, DELHI', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Vission - Perpetuating and transcending', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='transcending the processes of :', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Contributing to evolving supply chain', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='supply chain of human capital for', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='capital for National Economy', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Creating entrepreneurs and ‘game', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='and ‘game changers’ to support', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='to support heightened level of economic', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='of economic activities', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='underpinning ever increasing human', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='human aspiration', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Helping the Nation evolve as a total', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='as a total solution provider', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Value and wealth creation for the', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='for the mankind', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Mission - Focusing and practicing:', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Product and processes innovation', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Leveraging human cognitive and', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='cognitive and behavioral science for', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='science for creating instructional', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='instructional content', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Pervasive and ubiquitous Informat ion', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Informat ion Communication Technologies', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Technologies for customized content for', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='content for learning', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Acknowledge and facilitate various', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='various learning styles and learning', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='and learning abilities', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Migrating from teaching paradigm to', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='paradigm to learning paradigm', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Every day discourse shall inculcate', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='inculcate research culture and furt her', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='and furt her the cause of societal', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='of societal advancement', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Understand various markets and cultures', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='and cultures', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Collaborative learning and emotional', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='and emotional integrity', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Sensitizing about opportunities in', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='in Energy, Education, Environment and', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='and Health care sectors', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Extensively promoting computer aided', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='computer aided desi gn,analysis and', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='and manufacturing procedures', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Theoretical rigor to develop conceptual', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='conceptual clarity', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Modeling and design of experiments to', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='experiments to inculcate culture of', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='culture of investigation', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Helping foot print on Project', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='on Project management and collaborative', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='collaborative human endeavor', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Interdisciplinary st udies and exposure', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='and exposure to functional areas .', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Oue Competency - Coding Competency', metadata={'source': 'data\\About TSEC.pdf', 'page': 2}),
#  Document(page_content='Coding promotes logical and analytical', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='and analytical abilities, enhances', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='enhances entrepreneurial and pr oblem', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='and pr oblem -solving skills. It', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='helps in preparing young learners to', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='learners to become future', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='become future entrepreneurs. We, as an', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='We, as an institute are an early', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='mover in initiating students to', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='students to processes to help build', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='to help build competency in coding. We', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='in coding. We expose them to coding', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='through class room engagement ,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='engagement , practice sessions and', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='sessions and nudge them to develop an', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='to develop an interest in coding', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='through online portals meant for', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='meant for training and evaluating', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='and evaluating students on their', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='on their ability to remain focused for', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='long time for a set goal, problem', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='goal, problem solving ability,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='ability, competency in codifying', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='in codifying problem definitions,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='developing computer codes with minimal', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='with minimal time complexity, respect', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='respect for extreme boundary conditions', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='conditions of', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='problem definitions.', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='To motivate and inculcate coding', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='coding proficiency in students of TSEC,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='of TSEC, “TSEC Code Cell” & “TSEC Code', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='& “TSEC Code Storm”', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='societies are forme d. These societies', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='societies are student bodies that aim', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='that aim to nurture a keen interest in', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='programming within the students of TSEC', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='of TSEC and enhance their coding', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='their coding skills. Besides, students', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='students are', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='encouraged to participate in various', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='in various coding competitions', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='competitions conducted at state and', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='at state and nati onal level by', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='government agencies like Smart India', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Smart India Hackathon and IT/consulting', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='IT/consulting companies.', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Being the national level winner of', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='winner of AICTE conducted Smart India', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Smart India Hackathons (SIH), Ernst and', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Ernst and Young (E &', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Y), JP Morgan Chase, Myntra (27 lakhs', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='(27 lakhs pay package Pre -placement', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='-placement  offers given to the', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='given to the participating', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='students) are clear evidences of our', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='of our successful practices in this', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='in this regard.', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Campus Placement', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='TSEC has been the pioneer in setting up', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='in setting up a placement cell right', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='cell right since the inception even', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='inception even when it was', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='perceived as a superfluous department', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='department by most of the other p eer', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='other p eer colleges. TSEC has a strong', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='has a strong association', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='with industries around Mumbai –', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Mumbai – multinational and', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='and transnational enterprises. More', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='More than 90 enterprises', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='offer campus placement for our', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='for our graduates.', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Top companies such as Amazon, Ernst and', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Ernst and Young, JP Morgan, Deloitte,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Deloitte,  Deutsche Bank, Quantiphi,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Quantiphi, TCS,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Infosys, Accenture, LTI, BNP Paribas,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='BNP Paribas, Capgemini and many more', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='and many more visit the campus to', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='the campus to recruit students. The', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='placement being a function of market', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='of market driven forces it is directly', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='it is directly connected to the world', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='to the world economy & the', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='economy of the co untry.', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='The reflection of the variation in the', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='in the world economies and the economy', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='the economy of the country is clearly', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='is clearly visible', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='in the placement statistics.', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Social Outreach', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='The Practice aims to foster the spirit', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='the spirit of social responsibility in', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='in our students and sensitize the m to', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='the m to the', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='world of deprivation, social', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='social disparities and marginalization.', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='At TSEC, via student bodies like Unnat', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='like Unnat Bharat', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Abhiyaan, Ek Bharat Shreshtha Bharat,', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='Bharat, NSS and Rotaract club, we', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='club, we engage students in meaningful', metadata={'source': 'data\\About TSEC.pdf', 'page': 3}),
#  Document(page_content='community service, instilling a sense of', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='a sense of soci al obligation and', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='obligation and responsibility. We are', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='We are convinced of the fact', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='that education without social', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='without social commitment is incomplete', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='is incomplete and TSEC is committed to', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='committed to work for the', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='betterment of underprivileged section', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='section of the society and to help them', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='to help them through various outreach', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='progr ammes.', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='The college creates a synergy between', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='between its community work and outreach', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='and outreach through National Service', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='Scheme (NSS), thereby creating a multi', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='a multi -valued and mutually rewarding', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='rewarding forum for meaningful', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='for meaningful dialogues,', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='actions, and interactions. We are one', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='We are one of the first c olleges in', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='c olleges in Mumbai University to start', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='to start the NSS program', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='for engineering students. Projects', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='Projects carried out by NSS, like Blood', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='like Blood Donation Drives, Residential', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='Residential camps in', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='Rural Areas, Child Care Project etc.,', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='Project etc., engage students in a', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='students in a meaningful service to the', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='service to the society.', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='Core Competencies', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='Leveraging visual learning to maximize', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='to maximize the efficacy of learning', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='of learning process.', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
#  Document(page_content='Student -centred institutional', metadata={'source': 'data\\About TSEC.pdf', 'page': 4}),
# ...
#  Document(page_content='towards theoretical studies gets', metadata={'source': 'data\\About TSEC.pdf', 'page': 10}),
#  Document(page_content='normalized by improving the', metadata={'source': 'data\\About TSEC.pdf', 'page': 10}),
#  Document(page_content='improving the participation in', metadata={'source': 'data\\About TSEC.pdf', 'page': 10}),
#  Document(page_content='in hackathon by majority of stud ent', metadata={'source': 'data\\About TSEC.pdf', 'page': 10}),
#  Document(page_content='of stud ent community. The', metadata={'source': 'data\\About TSEC.pdf', 'page': 10}),
#  Document(page_content='objective of helping the students to', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='students to develop a temperament for', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='for understanding physical problem', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='problem domain', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='&amp; functional area shall be', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='area shall be massively improved by', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='improved by this initiative. The', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='The hackathons also contribute to', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='further the cause of small &amp;', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='small &amp;  medium scale industries', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='industries &amp; government/municipal', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='agencies which', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='are starved of cash/funding.', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='The Context :', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='India as a nation is blessed with', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='blessed with highly rigorous school', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='school education system which makes', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='which makes majority of the', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='students coming out of schools (10+2)', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='schools (10+2) equip ped with high', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='ped with high level of mathematical and', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='and analytical', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='integrities. Process designed to help', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='to help pupils develop proficiencies in', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='in developing software and hardware', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='solutions for digital systems makes', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='systems makes them sought after in', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='after in marketplace which is searching', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='is searching for talents wh o', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='can create new age solutions,', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='age solutions, leveraging converging', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='converging computational communication', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='communication technologies. We', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='are witnessing massive project funding', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='funding in western economies in search', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='in search of breakthrough technologies', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='and technology driven practices. These', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='These advanced economies are limited by', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='are limited by availability of techno', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='of techno savvy', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='human capitals and are promoting', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='are promoting international agreements', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='agreements for easy transfer of men and', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='of men and material', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='across the borders. India as an', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='India as an Information Technology', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='Technology behemoth exports IT product', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='IT product and services', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='whose value can be c ompared with', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='c ompared with revenue earned by Saudi', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='by Saudi Arabia in exporting their', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='their petroleum', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='products. So, we are determined to', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='determined to create a supply chain of', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='chain of Human capital for National', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='for National economy and to', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='cater to this ever growing demand for', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='demand for digital technology savvy', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='savvy manpower to contri bute to our', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='bute to our wealth', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='creation process. Hackathon is a tool', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='is a tool to drive sustained innovation', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='innovation and  crowdsource solutions', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='solutions  to', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='address challenges related to hardware', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='to hardware or software and figure out', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='and figure out a workable solution in a', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='solution in a stipulated', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='time. A hackathon is typically a time', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='a time -bound competitive event where', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='event where participants collaborate to', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='collaborate to build', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='proofs of concept and minimum viable', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='minimum viable products for a specific', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='for a specific pre -defined problem or', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='problem or to innovate.', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='Hackathon conceived by the political', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='the political establishment at the PMO', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='at the PMO level and disseminated by', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='by AICTE a nd', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='Innovation cell of Ministry of', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='of Ministry of Education has been the', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='has been the single most important co', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='important co -curricular activity. We', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='remain focused in a state of “No stone', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='of “No stone Unturned” to embrace the', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='to embrace the culture of Hackathon', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='of Hackathon amongst our', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='learners, and results in creating a', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='in creating a culture solution', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='solution building. These competency', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='competency building exercises of ours', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='is also the biggest key differentiator.', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='We encourage maximum participation in', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='in Hackathons (software/hardware)', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='getting organized at institute', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='level , Govt. Of India, AICTE and', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='AICTE and multinational corporate esse', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='corporate esse ntially meant for', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='meant for developing solutions for', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='public enterprises and succeeded in', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='succeeded in getting awards and cash', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='and cash prizes', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='The Practice :', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='We as an institute organise multiple', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='multiple Hackathons internally after', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='after carrying out a multitude of', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='preprocessing. Teachers and students', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='and students organise themselves to', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='themselves to design problems which are', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='which are socially', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='relevant and also identify bottlenecks', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='bottlenecks getting experienced by', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='experienced by various business sectors', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='sectors , which', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='encompasses agriculture , supply chain', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content=', supply chain management, heath care ,', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='heath care , traffic management ,', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='management , digital', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='commerce e tc.', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='At the beginning of academic year and', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='year and during admission to first year', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='to first year engineering, we', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='we explicitly high', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='lights the massive efforts of the', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='efforts of the institute in investing', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='in investing heavily in terms of time', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='terms of time and other resources as a', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='key differentiator. This institutional', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='institutional cultu re and competencies', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  Document(page_content='competencies catapult us in higher', metadata={'source': 'data\\About TSEC.pdf', 'page': 11}),
#  ...]

# %%
pinecone_instance = pinecone.Pinecone(api_key=PINECONE_API_KEY)

# %%
index_name = "mprbu"

# %%
import os 
os.environ['PINECONE_API_KEY'] = '3b6967cd-0235-4073-9d75-31e3ff580e38'

# %%
docsearch = PineconeStore.from_texts(
    [t.page_content for t in text_chunks],
    embedding,
    index_name=index_name
)

# %%
#if we already have an index we can load it like this
#docsearch=PineconeStore.from_existing_index(index_name,embeddings)

query = "I want Information about Archana Patankar"

docs=docsearch.similarity_search(query,k=3)
print("Result",docs)
# Out:
# Result [Document(page_content='2 Dr. Archana Patankar  Ph.D. (Engg.)'), Document(page_content='7 Prof. Anand Patwardhan'), Document(page_content='7 82 Aaditya Chinchkhedkar Informa tion')]

# %%
prompt_template = """
Use the following pieces of information to answer the user's question.
if you don't know the answer, just say that you don't know , don't try to make up answer.

Context:{context}
Question:{question}

Only return the helpful answer below and nothing else.
Helpful answer:
"""

# %%
PROMPT = PromptTemplate(input_variables=["context", "question"], template=prompt_template)
chain_type_kwargs = {"prompt": PROMPT}

# %%
llm = CTransformers(model="model\llama-2-7b-chat.ggmlv3.q4_0.bin",
model_type = "llama",config={'max_new_tokens':512,'temperature':0.8})

# %%
qa = RetrievalQA.from_chain_type(
    llm = llm,
    chain_type = "stuff",
    retriever = docsearch.as_retriever(search_kwargs={'k':2}),
    chain_type_kwargs=chain_type_kwargs
)

# %%
while True:
    user_input = input(f"Input Prompt: ")
    result = qa({"query": user_input})
    print("Response : ",result["result"])
# Out:
# c:\Hardik\Ai_tools\Chatbot_using_LLama2\Bot\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Response :  Dr. Archana Patankar is a highly experienced professor in the field of engineering with over 10 years of experience in teaching and research. She has published several papers in reputed journals and has presented her work at various conferences. Her areas of expertise include signal processing, image processing, and machine learning.
# Response :  The number of computers available for Computer Engineering students at XYZ University cannot be determined based on the information provided. The number of computers available varies depending on various factors such as the size of the university, the number of students enrolled, and the availability of resources. Additionally, it is important to note that computer engineering students typically have access to a variety of computing resources, including both hardware and software, as part of their academic program.
